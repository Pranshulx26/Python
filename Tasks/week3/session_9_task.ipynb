# %% [markdown]
# ### `Problem-1:` Class inheritence
#
# Create a **Bus** child class that inherits from the Vehicle class. The default fare charge of any vehicle is seating capacity * 100. If Vehicle is Bus instance, we need to add an extra 10% on full fare as a maintenance charge. So total fare for bus instance will become the final amount = total fare + 10% of the total fare.
#
# Note: The bus seating capacity is 50. so the final fare amount should be 5500. You need to override the fare() method of a Vehicle class in Bus class.

# %%
# Write code here
class Vehicle:
  def __init__(self, name, mileage, capacity):
    self.name = name
    self.mileage = mileage
    self.capacity = capacity
  def fare(self):
    return self.capacity * 100
  def __str__(self):
    return f"Name: {self.name}, Mileage: {self.mileage}, Capacity: {self.capacity}"


class Bus(Vehicle):
  def fare(self):
    return super().fare() * 1.1

b = Bus('Volvo', 234, 50)
b.fare()
# Out:
# 5500.0

# %% [markdown]
# ### `Problem-2:` Class Inheritence
#
# Create a Bus class that inherits from the Vehicle class. Give the capacity argument of *Bus.seating_capacity()* a default value of 50.
#
# Use the following code for your parent Vehicle class.

# %%
class Vehicle:
    def __init__(self, name, mileage, capacity):
        self.name = name
        self.mileage = mileage
        self.capacity = capacity

    def fare(self):
        return self.capacity * 100

    def __str__(self):
        return f"Name: {self.name}, Mileage: {self.mileage}, Capacity: {self.capacity}"
class Bus(Vehicle):
  def seating_capacity(self, capacity = 50):
    return f"The seating capacity of a {self.name} is {capacity} passengers"

b = Bus('Volvo', 234, 50)
b.seating_capacity()
# Out:
# 'The seating capacity of a Volvo is 50 passengers'

# %% [markdown]
# ### `Problem-3:` Write a program that has a class Point. Define another class Location which has two objects (Location & Destination) of class Point. Also define a function in Location that prints the reflection of Destination on the x axis.

# %%
class Point():
  def __init__(self, x, y):
    self.x = x
    self.y = y
  def __str__(self):
    return f"({self.x}, {self.y})"
class Location():
  def __init__(self, location, destination):
    self.location = location
    self.destination = destination

  def __str__(self):
    return f"Location: {self.location}, Destination: {self.destination}"

  def reflection(self):
    return f"The reflection of Destination on the x axis is ({self.destination.x}, {-self.destination.y})"
class Destination():
  def __init__(self, x, y):
    self.x = x
    self.y = y
  def __str__(self):
    return f"({self.x}, {self.y})"

# %% [markdown]
# ### `Problem-4:` Write a program that has an abstract class Polygon. Derive two classes Rectangle and Triamgle from Polygon and write methods to get the details of their dimensions and hence calculate the area.

# %%
from abc import ABC, abstractmethod
class Polygon(ABC):
  @abstractmethod
  def area(self):
    pass

class Rectangle(Polygon):
  def __init__(self, length, width):
    self.length = length
    self.width = width

  def area(self):
    return self.length * self.width

  def __str__(self):
    return f"Length: {self.length}, Width: {self.width}"

  def __repr__(self):
    return f"Rectangle({self.length}, {self.width})"

class Triangle(Polygon):
  def __init__(self, base, height):
    self.base = base
    self.height = height

  def area(self):
    return 0.5 * self.base * self.height

  def __str__(self):
    return f"Base: {self.base}, Height: {self.height}"

  def __repr__(self):
    return f"Triangle({self.base}, {self.height})"

r1 = Rectangle(10, 20)
print(r1)
print(r1.area())

t1 = Triangle(10, 20)
print(t1)
print(t1.area())
# Out:
# Length: 10, Width: 20
# 200
# Base: 10, Height: 20
# 100.0

# %% [markdown]
# ### `Problem-5:` Write a program with class Bill. The users have the option to pay the bill either by cheque or by cash. Use the inheritance to model this situation.

# %%
from abc import ABC, abstractmethod


class Bill(ABC):
    """
    Base class representing a bill.
    """

    def __init__(self, amount: float) -> None:
        self.amount = amount

    @abstractmethod
    def pay(self) -> None:
        """
        Process the payment.
        Must be implemented by subclasses.
        """
        pass


class CashBill(Bill):
    """
    Represents payment of bill via cash.
    """

    def pay(self) -> None:
        print(f"Bill of ₹{self.amount} paid successfully using Cash.")


class ChequeBill(Bill):
    """
    Represents payment of bill via cheque.
    """

    def __init__(self, amount: float, cheque_number: str, bank_name: str) -> None:
        super().__init__(amount)
        self.cheque_number = cheque_number
        self.bank_name = bank_name

    def pay(self) -> None:
        print(
            f"Bill of ₹{self.amount} paid using Cheque.\n"
            f"Cheque No: {self.cheque_number}, Bank: {self.bank_name}"
        )




cash_payment = CashBill(5000)
cash_payment.pay()

print()

cheque_payment = ChequeBill(10000, "CHK12345", "HDFC Bank")
cheque_payment.pay()
# Out:
# Bill of ₹5000 paid successfully using Cash.
#
# Bill of ₹10000 paid using Cheque.
# Cheque No: CHK12345, Bank: HDFC Bank

# %% [markdown]
# ###`Q-6:` FlexibleDict
# As of now we are accessing values from dictionary with exact keys. Now we want to amend accessing values functionality. if a dict have key `1` (int) the even if we try to access values by giving `'1'` (1 as str) as key, we should get the same result and vice versa.
#
# Write a class `FlexibleDict` upon builtin `dict` class with above required functionality.
#
# Hint- `dict[key] => dict.__getitem__(key)`

# %% [markdown]
# Ex.
# ```
# fd = FlexibleDict()
# fd['a'] = 100
# print(fd['a']) # Like regular dict
#
# fd[5] = 500
# print(fd[5]) # Like regular dict
#
# fd[1] = 100
# print(fd['1']) # actual Key is int but still trying to access through str key.
# fd['1'] = 100
# print(fd[1])
#
# ```
# `Output:`
# ```
# 100
# 500
# 100
# 100
#
# ```

# %%
class FlexibleDict(dict):
  """
  Dictionary that allows flexible access between int and str keys
  if they represent the same numeric value.
  """

  def __getitem__(self, key):
    if key in self:
      return super().__getitem__(key)

    alternate_key = self._convert_key(key)

    if alternate_key in self:
      return super().__getitem__(alternate_key)

    raise KeyError(key)

  @staticmethod
  def _convert_key(key):
      """
      Convert int to str or str digit to int.
      Otherwise return key unchanged.
      """
      if isinstance(key, int):
          return str(key)

      if isinstance(key, str) and key.isdigit():
          return int(key)

      return key

# %%
fd = FlexibleDict()
fd['a'] = 100
print(fd['a']) # Like regular dict

fd[5] = 500
print(fd[5]) # Like regular dict

fd[1] = 100
print(fd['1']) # actual Key is int but still trying to access through str key.
fd['1'] = 100
print(fd[1])
# Out:
# 100
# 500
# 100
# 100
