# %% [markdown]
# Some Theory
#
# Types of data used for I/O:
#
# - Text : '12345' as a sequence of unicode chars
# - Binary : 12345 as a sequence of bytes of its binary equivalent
#
# hence there are 2 file types to deal with
#
# - Text files - All program files are text files
# - Binary Files - Images, music, video, exe files

# %% [markdown]
# How File I/O is done in most programming languages
#
# 1. Open a file
# 2. Read/Write data
# 3. Close the file

# %% [markdown]
# Writing a file

# %%
# case 1 - if the file is not present

f = open('sample.txt', 'w')
f.write('hey my name is pranshul sharma. ')
f.close()

# %%
f.write('hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 f.write('hello')
#
# ValueError: I/O operation on closed file.

# %%
# write multiple strings
f = open('sample1.txt', 'w')
f.write('hello world')
f.write('\nhow are you?')
f.close()

# %%
# case 2 - if the file is alredy present
f = open('sample.txt', 'w')
f.write('hello')
f.close()

# %%
# how exactly open() works?

# when we call open() function
# it loads the file in the ram
# we do opeartions
# when we close the file
# it goes back to harddisk or ssd

# %%
# problem with w mode 
# introducing append mode 

# third line in sample1.txt 

f = open('sample1.txt', 'a')
f.write('\nI am fine')
f.close()

# %%
# write lines 
L = ['hello\n', 'hi\n', 'how are you\n', 'i am fine\n']

f = open('sample.txt', 'w')
f.writelines(L)
f.close()

# %%
# reading from files 
# -> using read()

f = open('sample.txt', 'r')
s = f.read()
print(s)
f.close()
# Out:
# hello
# hi
# how are you
# i am fine

# %%
# reading upto n chars
f = open('sample.txt', 'r')
s = f.read(10)
print(s)
f.close()
# Out:
# hello
# hi
# h

# %%
# readline() -> to read line by line 
f = open('sample.txt', 'r')
print(f.readline(), end='')
print(f.readline())
f.close()
# Out:
# hello
# hi

# %%
# reading entire using readline
f = open('sample.txt', 'r')

while True:
    data = f.readline()
    if data == '':
        break
    else:
        print(data, end='')

f.close()
# Out:
# hello
# hi
# how are you
# i am fine

# %% [markdown]
# Using Context Manager (with)
#
# - It's a good idea to close a file after usage as it will free up the resources
# - If we don't close it, garbage collector would close it.
# - with keyword closes the file as soon as the usage is over.

# %%
# with 
with open('sample.txt', 'r') as f:
    print(f.read())
# Out:
# hello
# hi
# how are you
# i am fine

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 f.read()
#
# ValueError: I/O operation on closed file.

# %%
# moving within a file -> 10 char then 10 char

with open('sample.txt', 'r') as f:
    print(f.read(10))
    print(f.read(10))
# Out:
# hello
# hi
# h
# ow are you

# %%
# benefit? -> to load a big file in memory
big_L = ['hello world' for i in range(1000)]

with open('big_txt', 'w') as f:
    f.writelines(big_L)

# %%
with open('big_txt', 'r') as f:
    chunk_size = 100
    while len(f.read(chunk_size)) > 0:
        print(f.read(chunk_size))
        # loading next chunk
        f.read(chunk_size)
# Out:
# ello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhe
# o worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello
# orldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello wo
# dhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello world
# llo worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhel
#  worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello
# rldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello wor
# hello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldh
# lo worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhell
# ...

# %%
# seek and tell function

with open('sample.txt', 'r') as f:
    print(f.read(10))
    print(f.tell())
    f.seek(0)
    print(f.read(10))
    print(f.tell())
# Out:
# hello
# hi
# h
# 12
# hello
# hi
# h
# 12

# %%
# seek during write 

with open('sample.txt' , 'w') as f:
    f.write('hello')
    f.seek(0)
    f.write('X')

# %% [markdown]
# Problems with working in text mode
#
# - Cant' work with binary files like images
# - not good for other data types like int/float/list/tuples

# %%
# working with binary file 
with open("C:\Users\yashs\Pictures\demo\car.jpg", 'r') as f:
    f.read()
# Out:
#   Cell In[35], line 2
#     with open("C:\Users\yashs\Pictures\demo\car.jpg", 'r') as f:
#                                                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# working with binary file
with open(r"C:\Users\yashs\Pictures\demo\car.jpg", 'rb') as f:
    with open('car.jpg', 'wb') as wf:
        wf.write(f.read())

# %%
# working with a big binary file

# %%
# working with other data types 
with open('sample.txt', 'w') as f:
    f.write(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 # working with other data types
#       2 with open('sample.txt', 'w') as f:
# ----> 3     f.write(2)
#
# TypeError: write() argument must be str, not int

# %%
with open('sample.txt', 'w') as f:
    f.write(str(2))

# %%
with open('sample.txt', 'r') as f:
    print(f.read() + 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 with open('sample.txt', 'r') as f:
# ----> 2     print(f.read() + 5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
with open('sample.txt', 'r') as f:
    print(int(f.read()) + 5)
# Out:
# 7

# %%
# more complex data

d = {
    'name' : 'pranshul',
    'age': 22,
    'gender': 'male'
}

with open('sample.txt', 'w') as f:
    f.write(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 10
#       3 d = {
#       4     'name' : 'pranshul',
#       5     'age': 22,
#       6     'gender': 'male'
#       7 }
#       9 with open('sample.txt', 'w') as f:
# ---> 10     f.write(d)
#
# TypeError: write() argument must be str, not dict

# %%
d = {
    'name' : 'pranshul',
    'age': 22,
    'gender': 'male'
}

with open('sample.txt', 'w') as f:
    f.write(str(d))

# %% [markdown]
# Serialization and Deserializtion
#
# - Serialization = process of converting python data types to json format
# - Deserialization = process of converting JSON to python data types

# %%
# serialization using json module
# list 

import json
l = [1, 2, 3, 4]

with open('demo.json', 'w') as f:
    json.dump(l, f)

# %%
# dict 

d = {
    'name' : 'pranshul',
    'age': 22,
    'gender': 'male'
}

with open('demo.json', 'w') as f:
    json.dump(d, f, indent=4)

# %%
# deserialization

with open('demo.json', 'r') as f:
    d = json.load(f)
    print(type(d))
# Out:
# <class 'dict'>

# %%
# serialize and deserialize tuple

t = (1, 2, 3, 4, 5)
with open('demo.json', 'w') as f:
    json.dump(t, f)
# it's stores as list

# %%
# serialize and deserialize a nest dict

d = {
    'student': 'pranshul',
    'marks': [1, 2, 2, 3, 4]
}

with open('demo.json', 'w') as f:
    json.dump(d, f)

# %% [markdown]
# Serializing and Deserializing custom objects

# %%
class Person:

    def __init__(self, fname, lname, age, gender):
        self.fname = fname
        self.lname = lname
        self.age = age 
        self.gender = gender

# format to printed in
# -> Nitish Singh age -> 33 gender -> male

# %%
person = Person('Nitish', 'Singh', 33, 'male')

# %%
# As a string 
import json 

with open('demo.json', 'w') as f:
    json.dump(person, f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 5
#       2 import json
#       4 with open('demo.json', 'w') as f:
# ----> 5     json.dump(person, f)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# ...

# %%
import json 

def show_object(person):
    if isinstance(person, Person):
        return f'{person.fname} {person.lname} age -> {person.age} gender -> {person.gender}'

with open('demo.json', 'w') as f:
    json.dump(person, f, default=show_object)

# %%
# As a dict
def show_object(person):
    if isinstance(person, Person):
        return {'name' : person.fname + person.lname, 'age': person.age, 'gender' : person.gender}

with open('demo.json', 'w') as f:
    json.dump(person, f, default=show_object)

# %%
# deserializing

with open('demo.json', 'r') as f:
    print(json.load(f))
# Out:
# {'name': 'NitishSingh', 'age': 33, 'gender': 'male'}

# %% [markdown]
# Pickling
#
# pickling is a process whereby a python object hierarchy is converted into a byte stream, and unpickling is the inverse operation, whereby as byte stream (from a binary file or bytes like object) is converted back into an object hierarchy.

# %%
class Person:

    def __init__(self, name, age):
        self.name = name 
        self.age = age

    def display_info(self):
        print('Hi my name is', self.name, 'and I am', self.age, 'years old')

# %%
p = Person('pranshul', 33)

# %%
# pickle dump 

import pickle 
with open('person.pkl', 'wb') as f:
    pickle.dump(p, f)

# %%
with open('person.pkl', 'rb') as f:
    obj = pickle.load(f)
    print(obj.name, obj.age)

obj.display_info()
# Out:
# pranshul 33
# Hi my name is pranshul and I am 33 years old

# %% [markdown]
# Pickle vs Json
#
# - Pickle lets the user to store data in binary format. Json lets the user store data in a human redeable text format.
